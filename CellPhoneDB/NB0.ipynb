# %%
# %%bash
# pwd
# Out:
# /home/jovyan/COVID/NB6_CellPhoneDB

# %%
# load some needed files here
import pandas as pd
import numpy as np

# %%
# !pip install xlrd==1.2.0
# Out:
# Collecting xlrd==1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 19.1 MB/s eta 0:00:01
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0

# %%
interactions_curated = pd.read_excel('/home/jovyan/COVID/NB6_CellPhoneDB/interaction_curated.xlsx', index_col = 0)

# %%
interactions_curated.columns
# Out:
# Index(['partner_a', 'partner_b', 'protein_name_a', 'protein_name_b',
#        'annotation_strategy', 'source', 'is_ppi', 'reactome_complex',
#        'reactome_reaction', 'reactome_pathway', 'complexPortal_complex',
#        'curator', 'comments', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38'],
#       dtype='object')

# %%
np.unique(interactions_curated['curator'], return_counts = True)
# Out:
# (array(['JRodriguezUbreva', 'LGarciaAlonso', 'RVentoTormo'], dtype=object),
#  array([   1,  397, 1339]))

# %%
interactions_curated = interactions_curated[interactions_curated['curator'] != 'LGarciaAlonso']
interactions_curated
# Out:
#                             partner_a          partner_b protein_name_a  \
# id_cp_interaction
# NaN                            Q9Y275             Q96RJ3    TN13B_HUMAN
# CPI-CC0041E1D30                  IL12      IL12_receptor            NaN
# CPI-CC0104F2A96    ACVR_1B2A_receptor  Activin_ligand_ab            NaN
# CPI-CC045C36F28    ACVR_1A2A_receptor  Activin_ligand_ab            NaN
# CPI-CC051643E98                  IL23      IL23_receptor            NaN
# ...                               ...                ...            ...
# NaN                            O14905             Q6FHJ7    WNT9B_HUMAN
# NaN                            O14905             Q8N474    WNT9B_HUMAN
# NaN                            O14905             Q92765    WNT9B_HUMAN
# NaN                            O14905             Q96HF1    WNT9B_HUMAN
# NaN                            O14905             Q9Y5W5    WNT9B_HUMAN
#
#                   protein_name_b annotation_strategy  \
# id_cp_interaction
# NaN                  TR13C_HUMAN             curated
# CPI-CC0041E1D30              NaN             curated
# CPI-CC0104F2A96              NaN             curated
# CPI-CC045C36F28              NaN             curated
# CPI-CC051643E98              NaN             curated
# ...                          ...                 ...
# NaN                  SFRP4_HUMAN             curated
# NaN                  SFRP1_HUMAN             curated
# NaN                  SFRP3_HUMAN             curated
# NaN                  SFRP2_HUMAN             curated
# NaN                   WIF1_HUMAN             curated
#
#                                                              source  is_ppi  \
# id_cp_interaction
# NaN                                                uniprot;reactome    True
# CPI-CC0041E1D30                                             uniprot    True
# CPI-CC0104F2A96                         PMID:22710174;PMID:22991378    True
# CPI-CC045C36F28    less_common_binding;PMID:22710174;PMID:22991378_    True
# CPI-CC051643E98                                             uniprot    True
# ...                                                             ...     ...
# NaN                                                   PMID:12775774    True
# NaN                                                   PMID:12775774    True
# NaN                                                   PMID:12775774    True
# NaN                                                   PMID:12775774    True
# NaN                                                   PMID:12775774    True
#
#                   reactome_complex reactome_reaction reactome_pathway  ...  \
# id_cp_interaction                                                      ...
# NaN                  R-HSA-5676540     R-HSA-5676599    R-HSA-1280215  ...
# CPI-CC0041E1D30                NaN               NaN              NaN  ...
# CPI-CC0104F2A96                NaN               NaN              NaN  ...
# CPI-CC045C36F28                NaN               NaN              NaN  ...
# CPI-CC051643E98                NaN               NaN              NaN  ...
# ...                            ...               ...              ...  ...
# NaN                            NaN               NaN              NaN  ...
# NaN                            NaN               NaN              NaN  ...
# NaN                            NaN               NaN              NaN  ...
# NaN                            NaN               NaN              NaN  ...
# NaN                            NaN               NaN              NaN  ...
#
#                    Unnamed: 29 Unnamed: 30 Unnamed: 31  Unnamed: 32  \
# id_cp_interaction
# NaN                        NaN         NaN         NaN          NaN
# CPI-CC0041E1D30            NaN         NaN         NaN          NaN
# CPI-CC0104F2A96            NaN         NaN         NaN          NaN
# CPI-CC045C36F28            NaN         NaN         NaN          NaN
# CPI-CC051643E98            NaN         NaN         NaN          NaN
# ...                        ...         ...         ...          ...
# NaN                        NaN         NaN         NaN          NaN
# NaN                        NaN         NaN         NaN          NaN
# NaN                        NaN         NaN         NaN          NaN
# NaN                        NaN         NaN         NaN          NaN
# NaN                        NaN         NaN         NaN          NaN
#
#                    Unnamed: 33  Unnamed: 34  Unnamed: 35  Unnamed: 36  \
# id_cp_interaction
# NaN                        NaN          NaN          NaN          NaN
# CPI-CC0041E1D30            NaN          NaN          NaN          NaN
# CPI-CC0104F2A96            NaN          NaN          NaN          NaN
# CPI-CC045C36F28            NaN          NaN          NaN          NaN
# CPI-CC051643E98            NaN          NaN          NaN          NaN
# ...                        ...          ...          ...          ...
# NaN                        NaN          NaN          NaN          NaN
# NaN                        NaN          NaN          NaN          NaN
# NaN                        NaN          NaN          NaN          NaN
# NaN                        NaN          NaN          NaN          NaN
# NaN                        NaN          NaN          NaN          NaN
#
#                    Unnamed: 37  Unnamed: 38
# id_cp_interaction
# NaN                        NaN          NaN
# CPI-CC0041E1D30            NaN          NaN
# CPI-CC0104F2A96            NaN          NaN
# CPI-CC045C36F28            NaN          NaN
# CPI-CC051643E98            NaN          NaN
# ...                        ...          ...
# NaN                        NaN          NaN
# NaN                        NaN          NaN
# NaN                        NaN          NaN
# NaN                        NaN          NaN
# NaN                        NaN          NaN
#
# [1340 rows x 38 columns]

# %%
complexes_curated = pd.read_excel('/home/jovyan/COVID/NB6_CellPhoneDB/complex_curated.xlsx', index_col = 0)

# %%
complexes_curated
# Out:
#                uniprot_1 uniprot_2 uniprot_3 uniprot_4  transmembrane  \
# complex_name
# Dopamine_byDDC    P20711       NaN       NaN       NaN          False
# GALR3             O60755    Q8TDV0       NaN       NaN           True
# GALR2             O43603    Q8TDV0       NaN       NaN           True
# GALR1             P47211    Q8TDV0       NaN       NaN           True
# BCR_CD45_CD22     P11274    P08575    P20273       NaN           True
# ...                  ...       ...       ...       ...            ...
# FZD8_LRP6         O75581    Q9H461       NaN       NaN           True
# FZD9_LRP5         O75197    O00144       NaN       NaN           True
# FZD9_LRP6         O75581    O00144       NaN       NaN           True
# FZD10_LRP5        O75197    Q9ULW2       NaN       NaN           True
# FZD10_LRP6        O75581    Q9ULW2       NaN       NaN           True
#
#                 peripheral  secreted secreted_desc  secreted_highlight  \
# complex_name
# Dopamine_byDDC       False      True   CHEBI:18243                True
# GALR3                False     False           NaN               False
# GALR2                False     False           NaN               False
# GALR1                False     False           NaN               False
# BCR_CD45_CD22        False     False           NaN               False
# ...                    ...       ...           ...                 ...
# FZD8_LRP6            False     False           NaN               False
# FZD9_LRP5            False     False           NaN               False
# FZD9_LRP6            False     False           NaN               False
# FZD10_LRP5           False     False           NaN               False
# FZD10_LRP6           False     False           NaN               False
#
#                 receptor  ... stoichiometry  comments_complex  \
# complex_name              ...
# Dopamine_byDDC     False  ...           NaN               NaN
# GALR3               True  ...           NaN               NaN
# GALR2               True  ...           NaN               NaN
# GALR1               True  ...           NaN               NaN
# BCR_CD45_CD22       True  ...           NaN               NaN
# ...                  ...  ...           ...               ...
# FZD8_LRP6          False  ...           NaN               NaN
# FZD9_LRP5          False  ...           NaN               NaN
# FZD9_LRP6          False  ...           NaN               NaN
# FZD10_LRP5         False  ...           NaN               NaN
# FZD10_LRP6         False  ...           NaN               NaN
#
#                 reactome_reaction reactome_complex complexPortal_complex  \
# complex_name
# Dopamine_byDDC       R-HSA-209859              NaN                   NaN
# GALR3                         NaN              NaN                   NaN
# GALR2                         NaN              NaN                   NaN
# GALR1                         NaN              NaN                   NaN
# BCR_CD45_CD22                 NaN              NaN                   NaN
# ...                           ...              ...                   ...
# FZD8_LRP6                     NaN              NaN                   NaN
# FZD9_LRP5                     NaN              NaN                   NaN
# FZD9_LRP6                     NaN              NaN                   NaN
# FZD10_LRP5                    NaN              NaN                   NaN
# FZD10_LRP6                    NaN              NaN                   NaN
#
#                rhea_reaction Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# complex_name
# Dopamine_byDDC    RHEA:18534         NaN         NaN         NaN         NaN
# GALR3                    NaN         NaN         NaN         NaN         NaN
# GALR2                    NaN         NaN         NaN         NaN         NaN
# GALR1                    NaN         NaN         NaN         NaN         NaN
# BCR_CD45_CD22            NaN         NaN         NaN         NaN         NaN
# ...                      ...         ...         ...         ...         ...
# FZD8_LRP6                NaN         NaN         NaN         NaN         NaN
# FZD9_LRP5                NaN         NaN         NaN         NaN         NaN
# FZD9_LRP6                NaN         NaN         NaN         NaN         NaN
# FZD10_LRP5               NaN         NaN         NaN         NaN         NaN
# FZD10_LRP6               NaN         NaN         NaN         NaN         NaN
#
# [397 rows x 26 columns]

# %%
interactions_curated.to_csv('./interactions_curated_subset_notLuz.tsv', sep = '\t')
complexes_curated.to_csv('./complex_curated.tsv', sep = '\t')

# %% [markdown]
# End of Notebook
