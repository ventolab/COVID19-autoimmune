# %%
# create environment and activate then install CellPhoneDB (Efremova, M. et al, Nature Protocols, 2020) here
# !python -m venv cpdb

# %%
# %%bash
#
# source ~/COVID/NB6_CellPhoneDB/cpdb/bin/activate

# %%
# !pip install cellphonedb
# Out:
# ...
#      |████████████████████████████████| 12.7 MB 2.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 128 kB 85.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 9.3 MB 76.7 MB/s eta 0:00:01
# ...
#   Using cached Flask_RESTful-0.3.8-py2.py3-none-any.whl (25 kB)
# ...
#      |████████████████████████████████| 50 kB 6.3 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 265 kB 75.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 108 kB 74.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 92 kB 136 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 7.0 MB 75.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 117 kB 79.4 MB/s eta 0:00:01
# ...
#   Using cached h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
# ...
#      |████████████████████████████████| 43 kB 620 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 71 kB 3.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 4.5 MB 74.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# convert .txt file to .csv
read_file = pd.read_csv (r'~/COVID/NB6_CellPhoneDB/gene_input.txt')
read_file.to_csv (r'~/COVID/NB6_CellPhoneDB/gene_input.csv', index = None)

# %%
# %%bash
#
# cd /home/jovyan/COVID/NB6_CellPhoneDB
#
# cellphonedb database generate \
#     --result-path database_20210402 \
#     --user-gene ./gene_input.csv \
#     --user-complex ./complex_curated.tsv \
#     --user-interactions ./interactions_curated_subset_notLuz.tsv
# Out:
# read local uniprot file
# [ ][APP][02/04/21-19:37:39][WARNING] Output directory (database_20210402) exist and is not empty. Result can overwrite old results
# read local ensembl file
# read local uniprot file
# [ ][APP][02/04/21-19:37:57][WARNING] Output directory (database_20210402) exist and is not empty. Result can overwrite old results
# [ ][APP][02/04/21-19:37:57][WARNING] There are differences between merged files: logged to database_20210402/log.txt
# [ ][APP][02/04/21-19:37:57][WARNING] Output directory (database_20210402) exist and is not empty. Result can overwrite old results
# [ ][APP][02/04/21-19:37:57][WARNING] Output directory (database_20210402) exist and is not empty. Result can overwrite old results
# [ ][APP][02/04/21-19:37:57][WARNING] Output directory (database_20210402) exist and is not empty. Result can overwrite old results
# Using local version for source InnateDB
# Using local version for source InnateDB-All
# Using local version for source IMEx
# ...

# %% [markdown]
# End of Notebook
